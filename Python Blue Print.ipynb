# %%
# Acquisition
## through a RESTful API
# eg http://www.python-requests .org/en/latest/

import requests
r = requests.get(r"https://api.github.com/users/acombs/starred")
print(r.json())


# Inspection 
 ## Inspect data before you go on.
# Out:
# [{'id': 266654506, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNjY2NTQ1MDY=', 'name': 'sidetable', 'full_name': 'chris1610/sidetable', 'private': False, 'owner': {'login': 'chris1610', 'id': 1223892, 'node_id': 'MDQ6VXNlcjEyMjM4OTI=', 'avatar_url': 'https://avatars0.githubusercontent.com/u/1223892?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chris1610', 'html_url': 'https://github.com/chris1610', 'followers_url': 'https://api.github.com/users/chris1610/followers', 'following_url': 'https://api.github.com/users/chris1610/following{/other_user}', 'gists_url': 'https://api.github.com/users/chris1610/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chris1610/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chris1610/subscriptions', 'organizations_url': 'https://api.github.com/users/chris1610/orgs', 'repos_url': 'https://api.github.com/users/chris1610/repos', 'events_url': 'https://api.github.com/users/chris1610/events{/privacy}', 'received_ev
# ...

# %%
#  --- Pandas ----
# documentation (htt p://pandas.pydata.org/pandas-docs/version/0.17.1/)

import os
import pandas as pd
import requests

# # request the data source
# PATH = r'/Volumes/Backup/python/pyton_blue_print/iris'

# # r= requests.get('https://archive.ics.uci.edu/ml/machine-learning-databases/iri s/iris.data')
# r = requests.get("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/")
# # url= requests.get("https://gist.github.com/curran/a08a1080b88344b0c8a7#file-iris-csv")

# with open(PATH + 'iris', 'w') as f:
#     f.write(r.text)

# os.chdir(PATH)

# df = pd.read_csv(PATH + 'iris.data', names=['sepal length', 'sepal width','petal length', 'petal width', 'class'])


# # df = pd.read_csv(url)

# df.head()

# %%
path= "https://raw.githubusercontent.com/kogilo/data_science_projects/master/data/Iris.csv"

df1 = pd.read_csv(path)

df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
 df1['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
# ata slicing is to use
#the .ix[row,column]
df1[['SepalLengthCm','SepalWidthCm']]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
# .iloc[row,column]


df1.iloc[:3,:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm
# 0   1            5.1           3.5
# 1   2            4.9           3.0
# 2   3            4.7           3.2

# %%
[x for x in df1.columns if x in ["SepalLengthCm", "SepalWidthCm"] ]
# Out:
# ['SepalLengthCm', 'SepalWidthCm']

# %%
df1[[x for x in df1.columns if x in ["SepalLengthCm", "SepalWidthCm"] ]]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
df1.loc[:3, [x for x in df1.columns if x in ["SepalLengthCm", "SepalWidthCm"]]]
# Out:
#    SepalLengthCm  SepalWidthCm
# 0            5.1           3.5
# 1            4.9           3.0
# 2            4.7           3.2
# 3            4.6           3.1

# %%
df1['Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df1['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df1['Species'] =='Iris-virginica'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: Species, Length: 150, dtype: bool

# %%
# dataframe where class == Iris-virginica
df1[df1['Species'] =='Iris-virginica']
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
# total count
df1.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
# count for Iris-virginica
df1[df1['Species'] =='Iris-virginica'].count()
# Out:
# Id               50
# SepalLengthCm    50
# SepalWidthCm     50
# PetalLengthCm    50
# PetalWidthCm     50
# Species          50
# dtype: int64

# %%
# saving it
# and reset index
virginica = df1[df1['Species'] =='Iris-virginica']
virginica.head(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
#
#             Species
# 100  Iris-virginica
# 101  Iris-virginica
# 102  Iris-virginica
# 103  Iris-virginica
# 104  Iris-virginica
# 105  Iris-virginica
# 106  Iris-virginica
# 107  Iris-virginica
# 108  Iris-virginica
# ...

# %%
# and reset index
virginica = df1[df1['Species'] =='Iris-virginica'].reset_index(drop=True)
virginica.head(10)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0  101            6.3           3.3            6.0           2.5
# 1  102            5.8           2.7            5.1           1.9
# 2  103            7.1           3.0            5.9           2.1
# 3  104            6.3           2.9            5.6           1.8
# 4  105            6.5           3.0            5.8           2.2
# 5  106            7.6           3.0            6.6           2.1
# 6  107            4.9           2.5            4.5           1.7
# 7  108            7.3           2.9            6.3           1.8
# 8  109            6.7           2.5            5.8           1.8
# 9  110            7.2           3.6            6.1           2.5
#
#           Species
# 0  Iris-virginica
# 1  Iris-virginica
# 2  Iris-virginica
# 3  Iris-virginica
# 4  Iris-virginica
# 5  Iris-virginica
# 6  Iris-virginica
# 7  Iris-virginica
# 8  Iris-virginica
# 9  Iris-virginica

# %%
 # Using original DataFrame and select data using two conditions:
    
df1['Species'] =='Iris-virginica'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: Species, Length: 150, dtype: bool

# %%
df1['SepalWidthCm'] >2.2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 145    True
# 146    True
# 147    True
# 148    True
# 149    True
# Name: SepalWidthCm, Length: 150, dtype: bool

# %%
# combine the two conditions

(df1['Species'] =='Iris-virginica') &  (df1['SepalWidthCm'] > 2.2)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Length: 150, dtype: bool

# %%
# Uning the combined conditions, qurey the data for df 
    # where :  classs == 'Iris-virginica 
    #.      :  SepalWidthCm > 2.2
    
# The DataFrame now includes data only from the Iris-virginica class with a petal width greater than 2.2.

df1[(df1['Species'] =='Iris-virginica') &  (df1['SepalWidthCm'] > 2.2)]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
# Get quick descriptive statistics from our Iris dataset:

# this is a default  percentiles (25%, 50%, 75%)
df1.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Can customize our percentiles === [.20,.40,.80,.90,.95]


df1.describe(percentiles=[.20,.40,.80,.90,.95])
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 20%     30.800000       5.000000      2.700000       1.500000      0.200000
# 40%     60.600000       5.600000      3.000000       3.900000      1.160000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 80%    120.200000       6.520000      3.400000       5.320000      1.900000
# 90%    135.100000       6.900000      3.610000       5.800000      2.200000
# 95%    142.550000       7.255000      3.800000       6.100000      2.300000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Check if there is correlation between these features

# Pearson correlation coefficient
df1.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
# The above function return default output, which is the 
# Pearson correlation coefficient for each row-column pair. 


# This can be switched to Kendall's tau or Spearman's rank correlation coefficient 
# by passing in a method argument (for instance, .corr(method="spearman") 
# or .corr(method="kendall")).

df1.corr(method="spearman")
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.734054     -0.411539       0.868498
# SepalLengthCm  0.734054       1.000000     -0.159457       0.881386
# SepalWidthCm  -0.411539      -0.159457      1.000000      -0.303421
# PetalLengthCm  0.868498       0.881386     -0.303421       1.000000
# PetalWidthCm   0.879045       0.834421     -0.277511       0.936003
#
#                PetalWidthCm
# Id                 0.879045
# SepalLengthCm      0.834421
# SepalWidthCm      -0.277511
# PetalLengthCm      0.936003
# PetalWidthCm       1.000000

# %% [markdown]
# ## Visualization
#
#     * how to visually inspect the data.

# %% [markdown]
# ## Th e Two important libraries are :

# %% [markdown]
# ### The matplotlib library
# * It is the great grandfather of Python plotting libraries.

# %%
# Now let's set up our Jupyter notebook 
# to allow us to see our graphs in line. 

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import numpy as np

# %%
# Now, let's generate our first graph on the 
# Iris dataset using the following code:


# creates a single subplot with a width of 6′′ and height of 4′′.
fig, ax = plt.subplots(figsize=(6,4))

# plot a histogram of the petal width from our iris
# DataFrame by calling .hist() and passing in our data. 
# set the bar color to black here.
ax.hist(df1['PetalWidthCm'], color='black');
ax.set_ylabel('Count', fontsize=12);
ax.set_xlabel('Width', fontsize=12);
plt.title('Iris Petal Width', fontsize=14, y=1.01);

# %%
# Let's now expand on this and generate histograms for each column of our iris dataset:

fig, ax = plt.subplots(2,2, figsize=(6,4));

# %%
fig, ax = plt.subplots(2,2, figsize=(6,4));
ax[0][0].hist(df1['PetalWidthCm'], color='black');
ax[0][0].set_ylabel('Count', fontsize=12);
ax[0][0].set_xlabel('Width', fontsize=12)
ax[0][0].set_title('Iris Petal Width', fontsize=14, y=1.01)
# Out:
# Text(0.5, 1.01, 'Iris Petal Width')

# %%
fig, ax = plt.subplots(2,2, figsize=(6,4));


ax[0][0].hist(df1['PetalWidthCm'], color='black');
ax[0][0].set_ylabel('Count', fontsize=12);
ax[0][0].set_xlabel('Width', fontsize=12)
ax[0][0].set_title('Iris Petal Width', fontsize=14, y=1.01)


ax[0][1].hist(df1['PetalLengthCm'], color='black');
ax[0][1].set_ylabel('Count', fontsize=12)
ax[0][1].set_xlabel('Lenth', fontsize=12)
ax[0][1].set_title('Iris Petal Lenth', fontsize=14, y=1.01);

ax[1][0].hist(df1['SepalWidthCm'], color='black');
ax[1][0].set_ylabel('Count', fontsize=12)
ax[1][0].set_xlabel('Width', fontsize=12)
ax[1][0].set_title('Iris Sepal Width', fontsize=14, y=1.01);


ax[1][1].hist(df1['SepalLengthCm'], color='black');
ax[1][1].set_ylabel('Count', fontsize=12)
ax[1][1].set_xlabel('Length', fontsize=12)
ax[1][1].set_title('Iris Sepal Length', fontsize=14, y=1.01)

#This method will nicely adjust the subplots automatically to avoid crowding.
plt.tight_layout()

# %%
# scatterplot.


fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(df1['PetalWidthCm'],df1['PetalLengthCm'], color='green')
ax.set_xlabel('Petal Width')
ax.set_ylabel('Petal Length')
ax.set_title('Petal Scatterplot')
# Out:
# Text(0.5, 1.0, 'Petal Scatterplot')

# %%
#  simple line plot


fig, ax = plt.subplots(figsize=(6,6))
ax.plot(df1['PetalLengthCm'], color='blue')
ax.set_xlabel('Specimen Number')
ax.set_ylabel('Petal Length')
ax.set_title('Petal Length Plot');

# %%
# the bar chart

# plot a bar chart for the mean of each 
# feature for the three classes of irises,


fig, ax = plt.subplots(figsize=(6,6))
bar_width = .8

labels = [x for x in df1.columns if x in ['SepalLengthCm', 'SepalLengthCm'] or  x in ['SepalWidthCm', 'PetalWidthCm']]

ver_y = [df1[df1['Species']=='Iris-versicolor'][x].mean() for x in labels]

vir_y = [df1[df1['Species']=='Iris-virginica'][x].mean() for x in labels]

set_y = [df1[df1['Species']=='Iris-setosa'][x].mean() for x in labels]

x = np.arange(len(labels))
ax.bar(x, vir_y, bar_width, bottom=set_y, color='darkgrey')

ax.bar(x, set_y, bar_width, bottom=ver_y, color='white')
ax.bar(x, ver_y, bar_width, color='black')
ax.set_xticks(x + (bar_width/2))
ax.set_xticklabels(labels, rotation=-70, fontsize=12);
ax.set_title('Mean Feature Measurement By Class', y=1.01)
ax.legend(['Virginica','Setosa','Versicolor']);

# %% [markdown]
# # The seaborn library

# %% [markdown]
# [seaborn](http://stanford.edu/~mwaskom/software/seaborn/index.html)

# %%
df1.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']

# %%
df2 = df1[cols]

# %%
import seaborn as sns
sns.pairplot(df2, hue="Species");

# %% [markdown]
# ## We learned about matplotlib to modify and work with seaborn.

# %%
fig, ax = plt.subplots(2, 2, figsize=(7, 7))
sns.set(style='white', palette='muted')

sns.violinplot(x=df2['Species'], y=df2['SepalLengthCm'], ax=ax[0,0])
sns.violinplot(x=df2['Species'], y=df2['SepalWidthCm'], ax=ax[0,1])

sns.violinplot(x=df2['Species'], y=df2['PetalLengthCm'], ax=ax[1,0])
sns.violinplot(x=df2['Species'], y=df2['PetalWidthCm'], ax=ax[1,1])

fig.suptitle('Violin Plots', fontsize=16, y=1.03)

for i in ax.flat:
    plt.setp(i.get_xticklabels(), rotation=-90)
fig.tight_layout()

# %% [markdown]
# ## Preparation

# %% [markdown]
# * Here we will learn about the
#     * Series.map(),
#     * Series.apply(),
#     * DataFrame.apply(),
#     * DataFrame.applymap(), and
#     * DataFrame.groupby() methods of pandas.
# * These are invaluable for working with data and are especially useful in the context of machine learning for feature engineering, a concept that we will discuss in detail in later chapters.

# %% [markdown]
# # Map

# %% [markdown]
# * The map method works on series,
# * so,we need `pandas Series`

# %% [markdown]
# * Suppose that we decide that the class names are a bit long for our taste and we would like to code them using our special three- letter coding system.
# * We'll use the map method with a Python dictionary as the argument to accomplish this. We'll pass in a replacement for each of the unique iris types:

# %%
df = pd.read_csv(path)

# %%
cols1 = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
       'Species']
df = df[cols1]

# %%
# df['Species'] = df['Species'].map({'Iris-setosa': 'SET', 'Iris-virginica':
#    'VIR', 'Iris-versicolor': 'VER'})
# df

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# The dictionary functionality is unique to the map method, and the most common reason to choose `map` over `apply` for a single column transformation. Let's now take a look at the `apply method`.

# %% [markdown]
# # Apply

# %% [markdown]
# * `apply` method allows us to work with both DataFrames and Series.
# * Let's now create a new column in our DataFrame, wide petal, that contains binary values based on the value in the petal width column.

# %% [markdown]
# * If the petal `width is equal to or wider than the median`, we will code it with a `1`, and if it is `less than the median`, we will code it `0`.

# %%
df['widePetalCm'] = df['PetalWidthCm'].apply(lambda v: 1 if v >= 1.3 else 0)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
#      widePetalCm
# ...

# %% [markdown]
# * This type of transformation is a fairly common `feature-engineering` transformation in machine learning, so it is good to be familiar with how to perform it.

# %% [markdown]
# * Let's now take a look at using apply on a DataFrame rather than a single Series. We'll now create a feature based on petal area:

# %%
df['petalAreaCmsqr'] = df.apply(lambda r: r['PetalLengthCm'] * r['PetalWidthCm'],
   axis=1)

df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
#      widePetalCm  petalAreaCmsqr
# ...

# %% [markdown]
# * we passed in `axis=1` in order to tell pandas that we want to apply the function `row-wise`.
# * If we passed in `axis=0`, then the function would operate `column-wise`.
#
# * is what makes pandas an indispensable tool for data manipulation.

# %% [markdown]
# # Applymap

# %% [markdown]
# * suppose that you'd like to perform a function across all data cells in your DataFrame;

# %%
df.applymap(lambda v: np.log(v) if isinstance(v, float) else v)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 0         1.629241      1.252763       0.336472     -1.609438     Iris-setosa
# 1         1.589235      1.098612       0.336472     -1.609438     Iris-setosa
# 2         1.547563      1.163151       0.262364     -1.609438     Iris-setosa
# 3         1.526056      1.131402       0.405465     -1.609438     Iris-setosa
# 4         1.609438      1.280934       0.336472     -1.609438     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145       1.902108      1.098612       1.648659      0.832909  Iris-virginica
# 146       1.840550      0.916291       1.609438      0.641854  Iris-virginica
# 147       1.871802      1.098612       1.648659      0.693147  Iris-virginica
# 148       1.824549      1.223775       1.686399      0.832909  Iris-virginica
# 149       1.774952      1.098612       1.629241      0.587787  Iris-virginica
#
#      widePetalCm  petalAreaCmsqr
# ...

# %% [markdown]
# * Here, we called applymap on our DataFrame in order to get the log of every value (np.log() utilizes the numpy library to return this value) if that value is an instance of the type float.

# %% [markdown]
# # Groupby

# %% [markdown]
# * The `groupby` operation does exactly what it says—it groups data based on some class or classes that you choose.

# %%
df.groupby('Species').mean()
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# Species
# Iris-setosa              5.006         3.418          1.464         0.244
# Iris-versicolor          5.936         2.770          4.260         1.326
# Iris-virginica           6.588         2.974          5.552         2.026
#
#                  widePetalCm  petalAreaCmsqr
# Species
# Iris-setosa              0.0          0.3628
# Iris-versicolor          0.7          5.7204
# Iris-virginica           1.0         11.2962

# %% [markdown]
# * Data for each class is partitioned and the mean for each feature is provided.
# * Let's take it a step further now and get full descriptive statistics for each class:

# %%
df.groupby('Species').describe()
# Out:
#                 SepalLengthCm                                              \
#                         count   mean       std  min    25%  50%  75%  max
# Species
# Iris-setosa              50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor          50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica           50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 SepalWidthCm         ... widePetalCm      petalAreaCmsqr  \
#                        count   mean  ...         75%  max          count
# Species                              ...
# Iris-setosa             50.0  3.418  ...         0.0  0.0           50.0
# Iris-versicolor         50.0  2.770  ...         1.0  1.0           50.0
# Iris-virginica          50.0  2.974  ...         1.0  1.0           50.0
#
#
#                     mean       std   min     25%     50%    75%    max
# Species
# Iris-setosa       0.3628  0.183248  0.11  0.2650   0.300   0.42   0.96
# ...

# %%
df.groupby('PetalWidthCm')['Species'].unique().to_frame()
# Out:
#                                         Species
# PetalWidthCm
# 0.1                               [Iris-setosa]
# 0.2                               [Iris-setosa]
# 0.3                               [Iris-setosa]
# 0.4                               [Iris-setosa]
# 0.5                               [Iris-setosa]
# 0.6                               [Iris-setosa]
# 1.0                           [Iris-versicolor]
# 1.1                           [Iris-versicolor]
# 1.2                           [Iris-versicolor]
# 1.3                           [Iris-versicolor]
# 1.4           [Iris-versicolor, Iris-virginica]
# 1.5           [Iris-versicolor, Iris-virginica]
# 1.6           [Iris-versicolor, Iris-virginica]
# 1.7           [Iris-versicolor, Iris-virginica]
# 1.8           [Iris-versicolor, Iris-virginica]
# 1.9                            [Iris-virginica]
# 2.0                            [Iris-virginica]
# 2.1                            [Iris-virginica]
# ...

# %% [markdown]
# * Let's now take a look at a custom aggregation function:

# %%
#  df.groupby('Species')['PetalWidthCm'].agg({lambda x: x.max() - x.min(), 'max': np.max, 'min': np.min })

# %% [markdown]
# [groupby]( http://pandas.pydata.org/pandas-docs/stable/)
