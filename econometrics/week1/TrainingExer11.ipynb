# %%
import pandas as pd
import seaborn as sns
import numpy as np
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("TrainExer11.xls")

# %%
df.head()
# Out:
#    Observation  Age  Expenditures
# 0            1   49            95
# 1            2   15           104
# 2            3   43            91
# 3            4   45            98
# 4            5   40            94

# %%
df.describe()
# Out:
#        Observation        Age  Expenditures
# count    26.000000  26.000000     26.000000
# mean     13.500000  39.346154    101.115385
# std       7.648529  10.639332      6.107876
# min       1.000000  15.000000     89.000000
# 25%       7.250000  35.000000     96.000000
# 50%      13.500000  39.500000    103.000000
# 75%      19.750000  45.750000    106.750000
# max      26.000000  57.000000    109.000000

# %% [markdown]
# ### (a) Make two histograms, one of expenditures and the other of age. Make also a scatter diagram with expenditures on the vertical axis versus age on the horizontal axis.

# %%
num_bins = 12
n, bins, patches = plt.hist(df["Expenditures"], num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Expenditures')
plt.ylabel('Frequency')
plt.show()

# %%
num_bins = 12
n, bins, patches = plt.hist(df["Age"], num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
x = df["Age"]
y = df["Expenditures"]
# color = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x, y, s=area, alpha=0.5)
plt.title('Scatter Diagram of Expenditures aganist Age')
plt.xlabel('Age')
plt.ylabel('Expenditures')
plt.show()

# %% [markdown]
# #### (b) In what respect do the data in this scatter diagram look different from the case of the sales and price data
# discussed in the lecture?
#
#
#
# AN: There seem to be two groups. group with age<40 and age>=40

# %% [markdown]
# #### (c) Propose a method to analyze these data in a way that assists the travel agent in making recommendations to future clients.
#
# AN: The Promotion should be focus on the travelers who are in the mid-age group.

# %% [markdown]
# ### The scatter diagram indicates two groups of clients. Younger clients spend more than older ones. Further, expenditures tend to increase with age for younger clients, whereas the pattern is less clear for older clients.

# %% [markdown]
# #### (d) Compute the sample mean of expenditures of all 26 clients.

# %%
mean = df['Expenditures'].mean()
print("Average Expenditures: ", mean)
# Out:
# Average Expenditures:  101.11538461538461

# %% [markdown]
# #### (e) Compute two sample means of expenditures, one for clients of age forty or more and the other for clients of age below forty.

# %%
print("Means of expenditures for Age >= 40: ", df[df['Age'] >= 40]["Expenditures"].mean())
# Out:
# Means of expenditures for Age >= 40:  95.84615384615384

# %%
print("Means of expenditures for Age < 40: ", df[df['Age'] < 40]["Expenditures"].mean())
# Out:
# Means of expenditures for Age < 40:  106.38461538461539

# %% [markdown]
# ### (f) What daily expenditures would you predict for a new client of fifty years old? And for someone who is twenty-five years old?
#
#
# ANS: Someone with Age = 50 === 95.85
#
# ANS: Someone with Age = 25 === 106.39
