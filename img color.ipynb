# %%
from PIL import Image, ImageFile, BmpImagePlugin
import numpy as np
import matplotlib.pyplot as plt

# %%
im = Image.open('abella.jpg')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
def main(): 
    try: 
        #Relative Path 
        img = Image.open("abella.jpg")  
          
        #splitting the image 
        print (img.split() )
    except IOError: 
        pass

if __name__ == "__main__": 
    main()
# Out:
# (<PIL.Image.Image image mode=L size=620x640 at 0x11C1AF810>, <PIL.Image.Image image mode=L size=620x640 at 0x11C1A75D0>, <PIL.Image.Image image mode=L size=620x640 at 0x11F980110>)

# %%
def main(): 
    try: 
        #Relative Path 
        img = Image.open("abella.jpg")  
        print (img.mode )
          
        #converting image to bitmap 
        print( img.tobitmap() )
          
        print( type(im.tobitmap()) )
    except IOError: 
        pass

if __name__ == "__main__": 
    main()
# Out:
# RGB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-b651272ac08a> in <module>
#      13
#      14 if __name__ == "__main__":
# ---> 15     main()
#
# <ipython-input-47-b651272ac08a> in main()
#       6
#       7         #converting image to bitmap
# ----> 8         print( img.tobitmap() )
#       9
#      10         print( type(im.tobitmap()) )
#
# /opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in tobitmap(self, name)
#     736         self.load()
#     737         if self.mode != "1":
# --> 738             raise ValueError("not a bitmap")
#     739         data = self.tobytes("xbm")
#     740         return b"".join(
#
# ValueError: not a bitmap

# %%
def convert_to_grayscale(image):
    grayscale = image.convert("L")
    return grayscale

grayscale = convert_to_grayscale(im)
grayscale.show()

# %%
import PIL


def get_binary_image(image, threshold):
    grayscale = convert_to_grayscale(image)
    arr = np.array(grayscale)
    
    for i in range(0, len(arr)):
        for j in range(0, len(arr[i])):
            if arr[i][j] >= threshold:
                arr[i][j] = 255
            else:
                arr[i][j] = 0
    return PIL.Image.fromarray(arr)

bin_image = get_binary_image(im, 110)
bin_image.show()

# %%
arr = np.array(im)

# %%
arr
# Out:
# array([[[126, 104,  83],
#         [126, 104,  83],
#         [126, 104,  83],
#         ...,
#         [244, 223, 202],
#         [242, 221, 200],
#         [243, 222, 201]],
#
#        [[125, 104,  83],
#         [125, 104,  83],
#         [126, 104,  83],
#         ...,
#         [242, 224, 202],
#         [242, 221, 200],
#         [244, 223, 202]],
#
#        [[126, 104,  83],
#         [126, 104,  83],
#         [126, 104,  83],
#         ...,
#         [243, 225, 203],
#         [243, 222, 201],
#         [244, 223, 202]],
#
#        ...,
#
#        [[ 15,  10,  16],
#         [ 16,  11,  17],
#         [ 16,  11,  17],
#         ...,
#         [ 71,  53,  51],
#         [ 69,  51,  49],
#         [ 71,  53,  49]],
#
#        [[ 15,  10,  16],
#         [ 16,  11,  17],
#         [ 16,  11,  17],
#         ...,
#         [ 71,  53,  51],
#         [ 69,  51,  49],
#         [ 70,  52,  50]],
#
#        [[ 16,  11,  17],
#         [ 17,  12,  18],
#         [ 17,  12,  18],
# ...

# %%
arr.shape
# Out:
# (640, 620, 3)

# %%
plt.imshow(arr);

# %%
gray = arr.mean(axis=2)

# %%
gray.shape
# Out:
# (640, 620)

# %%
grayscale_image = im.convert("L")
grayscale_array = np.asarray(grayscale_image)

plt.imshow(grayscale_array, cmap="gray");

# %%
plt.imshow(gray)

# %%
plt.imshow(gray, cmap="gray");

# %%
fig, ax = plt.subplots()
ax.imshow(gray, cmap="gray")
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %%
# resizing the image 
im.thumbnail((50, 50), Image.ANTIALIAS) 
imgplot = plt.imshow(im)

# %%
imgplot = plt.imshow(im, interpolation="nearest")

# %%
plt.imshow(im, cmap="hot")

# %%
import json
import pandas as pd

# %%
grayscale_image = im.convert("L")
grayscale_array = np.asarray(grayscale_image)

plt.imshow(grayscale_array, cmap="gray");

# %%
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, ax = plt.subplots()

ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# arr_lena = mpimg.imread('Lenna.png')

imagebox = OffsetImage(im, zoom=3.5)

ab = AnnotationBbox(imagebox, (0.4, 0.6))

ax.add_artist(ab)

plt.grid()

plt.draw()
plt.savefig('add_picture_matplotlib_figure.png',bbox_inches='tight')
plt.show();
